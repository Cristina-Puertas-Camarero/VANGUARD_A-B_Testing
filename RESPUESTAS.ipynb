# %% [markdown]
# ## RESPUESTAS
#
# 1. ¿Quiénes son los principales clientes que utilizan este proceso en línea?
#
# Edad promedio (Test): 48.7506482767931
# Edad promedio (Control): 48.30989554278701
#
# Ingresos promedio (Test): 164483.515852941
# Ingresos promedio (Control): 159398.6389989541
#
# Antigüedad promedio (Test): 12.6835485818535
# Antigüedad promedio (Control): 12.670695044856599
#
# 2. ¿Los clientes principales son más jóvenes o mayores, nuevos o antiguos?
#
#
# 3. Análisis del comportamiento del cliente.

# %% [markdown]
# ## KPI (Indicadores clave de rendimiento)
#
# 1. Tasa de finalización : la proporción de usuarios que llegan al paso final de "confirmación"
#
# Usuarios que completaron el proceso (Test): 18687
# Usuarios que completaron el proceso (Control): 15434
#
# Usuarios que no completaron el proceso (Test): 8279
# Usuarios que no completaron el proceso (Control): 8098
#
#
#
# 2. Tiempo dedicado a cada paso : la duración promedio que los usuarios dedican a cada paso.
#
# Tiempo promedio entre pasos (Test):
# process_step
# start     2.452503
# step_1    0.628393
# step_2    0.802194
# step_3    1.614183
#
#
# Tiempo promedio entre pasos (Control):
# process_step
# start     2.522767
# step_1    0.716646
# step_2    0.644464
# step_3    1.549071
#
#
# 3. Tasas de error : si hay un paso en el que los usuarios vuelven a un paso anterior, puede indicar confusión o un error. Debe considerar que pasar de un paso posterior a uno anterior es un error.
#
# Tasa de error (Test): 3.800632911392405
# Tasa de error (Control): 3.754166666666667
#
# 4. En función de los KPI elegidos, ¿cómo se compara el rendimiento del nuevo diseño con el anterior?
#
# Resumen de los KPI
#
# Tasa de finalización (Test): 69.30%
# Tasa de finalización (Control): 65.59%
# Aumento observado en la tasa de finalización: 3.71%
# Tasa de error (Test): 3.80
# Tasa de error (Control): 3.75
#
# Tiempo promedio entre pasos (Test):
# process_step
# start     2.452503
# step_1    0.628393
# step_2    0.802194
# step_3    1.614183
#
#
# Tiempo promedio entre pasos (Control):
# process_step
# start     2.522767
# step_1    0.716646
# step_2    0.644464
# step_3    1.549071

# %% [markdown]
# ## Hipótesis para sacar conclusiones basadas en datos sobre la eficacia del rediseño
#
# 1. Tasa de finalización
#
# Estadístico t: -1.3764143769002999
# Valor p: 0.16870241210362807
# No podemos rechazar la hipótesis nula. No hay una diferencia significativa en la tasa de finalización entre los grupos de prueba y de control.
#
# 2. Tasa de finalización con un umbral de costo-efectividad
#
# El aumento observado en la tasa de finalización (3.71%) no cumple con el umbral del 5%.
#
# 3. Edad promedio de los clientes que interactúan con el nuevo proceso es la misma que la de los que interactúan con el proceso anterior
#
# Estadístico t: 7.937665504659508
# Valor p: 2.066796718678905e-15
# Rechazamos la hipótesis nula. Hay una diferencia significativa en la edad promedio entre los grupos de prueba y de control.
#
# 4. permanencia promedio del cliente (cuánto tiempo han estado con Vanguard) de aquellos que interactúan con el nuevo proceso es la misma que la de aquellos que interactúan con el proceso anterior.
#
# Estadístico t: 0.5222569822079763
# Valor p: 0.6014917765459376
# No podemos rechazar la hipótesis nula. No hay una diferencia significativa en la permanencia promedio entre los grupos de prueba y de control.
#
# 5. existen diferencias de género que afecten la participación en el proceso nuevo o antiguo.
#
# Estadístico chi-cuadrado: 47.84376103857565
# Valor p: 4.0818711710883206e-11
# Rechazamos la hipótesis nula. Hay una diferencia significativa en la participación por género entre los grupos de prueba y de control.

# %% [markdown]
# ## Evaluación del experimento
#
# ### EFICACIA DEL DISEÑO
#
# 1. ¿El experimento estuvo bien estructurado?
#
# 2. ¿Los clientes se dividieron de forma aleatoria y equitativa entre los diseños antiguos y los nuevos?
#
# 3. ¿Hubo algún sesgo?
#
# ### EVALUACIÓN DE DURACIÓN
#
# 1. ¿Fue el período de tiempo del experimento (del 15/3/2017 al 20/6/2017) adecuado para recopilar datos y conocimientos significativos?
#
#
# ### NECESIDADES DE DATOS ADICIONALES
#
# 1.  ¿Qué otros datos, si estuvieran disponibles, podrían mejorar el análisis?
